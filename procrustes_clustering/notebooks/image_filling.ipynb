# %% [markdown]
# # Creating an Image from Landmark Points
#
# We extract the landmark points for alignment, but in the last step we create an image with its intererior filled.

# %%
from wand.image import Image as WImage
from IPython.display import Image

# %%
WImage(filename="../figs/image_to_filled_1.pdf")
# Out:
# <wand.image.Image: 1c4fadb 'PDF' (432x1440)>

# %% [markdown]
# Below we see that if we don't choose enough points when extracting the shape the filling will not work.

# %%
WImage(filename="../figs/image_to_filled_3.pdf")
# Out:
# <wand.image.Image: f6536e3 'PDF' (432x1440)>

# %%
WImage(filename="../figs/image_to_filled_5.pdf")
# Out:
# <wand.image.Image: 6b8cdf3 'PDF' (432x1440)>

# %%
WImage(filename="../figs/image_to_filled_5_2.pdf")
# Out:
# <wand.image.Image: e611f91 'PDF' (432x1440)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_11.pdf")
# Out:
# <wand.image.Image: 94e1982 'PDF' (864x216)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_33.pdf")
# Out:
# <wand.image.Image: 9de645d 'PDF' (864x216)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_13.pdf")
# Out:
# <wand.image.Image: a01c84a 'PDF' (864x216)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_77.pdf")
# Out:
# <wand.image.Image: b633ef7 'PDF' (864x216)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_55.pdf")
# Out:
# <wand.image.Image: 5a69bb4 'PDF' (864x216)>

# %%
WImage(filename="../figs/shape_to_fill_comparison_57.pdf")
# Out:
# <wand.image.Image: 18843c9 'PDF' (864x216)>

# %% [markdown]
# Adding more points and increasing the scaling can make the final image a little better.

# %%
WImage(filename="../figs/shape_to_fill_comparison_more.pdf")
# Out:
# <wand.image.Image: 5f258ab 'PDF' (864x216)>

# %% [markdown]
# ## Clustering

# %% [markdown]
# Clustering $\{1,3\}$:
# $$
# \begin{array}{}
# \mbox{Method} & N_i=20 & N_i=30 & N_i=40  \\
# \hline
# \mbox{Euclidean} & 0.885000 &  0.906667 & 0.877500 \\
# \mbox{Procrustes} & 0.905000 & 0.936667 &  0.900000 \\
# \mbox{Procrustes Filling} & 0.935000 & 0.970000 & 0.952500
# \end{array}
# $$
# Clustering $\{1,3,5\}$:
# $$
# \begin{array}{}
# \mbox{Method} & N_i=20 & N_i=30 & N_i=40  \\
# \hline
# \mbox{Euclidean} & 0.636667 &  0.702222  & 0.660000 \\
# \mbox{Procrustes} & 0.656667 & 0.842222 &   0.731667 \\
# \mbox{Procrustes Filling} & 0.810000 & 0.808889 &  0.798333
# \end{array}
# $$
